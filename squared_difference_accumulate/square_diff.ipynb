# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
sys.path.append('/home/xilinx')
from pynq import Overlay
import numpy as np
def square_diff():
    for i in range(1,9):
        print("==================================================================")
        for j in range(1,9):
            regIP.write(0x400, i)
            regIP.write(0x800, j )
            out = regIP.read(0xc00)
            print("IP    Square_diff of (%f - %f)^2= %f\n"%(i, j, out  ))
            print("Numpy Square_diff of (%f - %f)^2= %f\n"%(i, j, (i-j)**2  ))
            print("==================================================================")
            


if __name__ == "__main__":
    print("Entry:", sys.argv[0])
    print("System argument(s):", len(sys.argv))

    print("Start of \"" + sys.argv[0] + "\"")
    ol = Overlay("/home/xilinx/bitstream/Square_diff.bit")
    regIP = ol.top_process_magnitude_0    
    square_diff()
    print("Exit process")
# Out:
# Entry: /usr/lib/python3/dist-packages/ipykernel_launcher.py
# System argument(s): 3
# Start of "/usr/lib/python3/dist-packages/ipykernel_launcher.py"
# ==================================================================
# IP    Square_diff of (1.000000 - 1.000000)^2= 0.000000
#
# Numpy Square_diff of (1.000000 - 1.000000)^2= 0.000000
#
# ==================================================================
# IP    Square_diff of (1.000000 - 2.000000)^2= 1.000000
#
# Numpy Square_diff of (1.000000 - 2.000000)^2= 1.000000
#
# ==================================================================
# IP    Square_diff of (1.000000 - 3.000000)^2= 4.000000
#
# Numpy Square_diff of (1.000000 - 3.000000)^2= 4.000000
#
# ==================================================================
# IP    Square_diff of (1.000000 - 4.000000)^2= 9.000000
#
# Numpy Square_diff of (1.000000 - 4.000000)^2= 9.000000
#
# ==================================================================
# IP    Square_diff of (1.000000 - 5.000000)^2= 16.000000
#
# Numpy Square_diff of (1.000000 - 5.000000)^2= 16.000000
#
# ==================================================================
# IP    Square_diff of (1.000000 - 6.000000)^2= 25.000000
#
# Numpy Square_diff of (1.000000 - 6.000000)^2= 25.000000
#
# ==================================================================
# IP    Square_diff of (1.000000 - 7.000000)^2= 36.000000
#
# Numpy Square_diff of (1.000000 - 7.000000)^2= 36.000000
#
# ==================================================================
# IP    Square_diff of (1.000000 - 8.000000)^2= 49.000000
#
# Numpy Square_diff of (1.000000 - 8.000000)^2= 49.000000
#
# ==================================================================
# ==================================================================
# IP    Square_diff of (2.000000 - 1.000000)^2= 1.000000
#
# Numpy Square_diff of (2.000000 - 1.000000)^2= 1.000000
#
# ==================================================================
# IP    Square_diff of (2.000000 - 2.000000)^2= 0.000000
#
# Numpy Square_diff of (2.000000 - 2.000000)^2= 0.000000
#
# ==================================================================
# IP    Square_diff of (2.000000 - 3.000000)^2= 1.000000
#
# Numpy Square_diff of (2.000000 - 3.000000)^2= 1.000000
#
# ==================================================================
# IP    Square_diff of (2.000000 - 4.000000)^2= 4.000000
#
# Numpy Square_diff of (2.000000 - 4.000000)^2= 4.000000
#
# ==================================================================
# IP    Square_diff of (2.000000 - 5.000000)^2= 9.000000
#
# Numpy Square_diff of (2.000000 - 5.000000)^2= 9.000000
#
# ==================================================================
# IP    Square_diff of (2.000000 - 6.000000)^2= 16.000000
#
# Numpy Square_diff of (2.000000 - 6.000000)^2= 16.000000
#
# ==================================================================
# IP    Square_diff of (2.000000 - 7.000000)^2= 25.000000
#
# Numpy Square_diff of (2.000000 - 7.000000)^2= 25.000000
#
# ==================================================================
# IP    Square_diff of (2.000000 - 8.000000)^2= 36.000000
#
# Numpy Square_diff of (2.000000 - 8.000000)^2= 36.000000
#
# ==================================================================
# ==================================================================
# IP    Square_diff of (3.000000 - 1.000000)^2= 4.000000
#
# Numpy Square_diff of (3.000000 - 1.000000)^2= 4.000000
#
# ==================================================================
# IP    Square_diff of (3.000000 - 2.000000)^2= 1.000000
#
# Numpy Square_diff of (3.000000 - 2.000000)^2= 1.000000
#
# ==================================================================
# IP    Square_diff of (3.000000 - 3.000000)^2= 0.000000
#
# Numpy Square_diff of (3.000000 - 3.000000)^2= 0.000000
#
# ==================================================================
# IP    Square_diff of (3.000000 - 4.000000)^2= 1.000000
#
# Numpy Square_diff of (3.000000 - 4.000000)^2= 1.000000
#
# ==================================================================
# IP    Square_diff of (3.000000 - 5.000000)^2= 4.000000
#
# Numpy Square_diff of (3.000000 - 5.000000)^2= 4.000000
#
# ==================================================================
# IP    Square_diff of (3.000000 - 6.000000)^2= 9.000000
#
# Numpy Square_diff of (3.000000 - 6.000000)^2= 9.000000
#
# ==================================================================
# IP    Square_diff of (3.000000 - 7.000000)^2= 16.000000
#
# Numpy Square_diff of (3.000000 - 7.000000)^2= 16.000000
#
# ==================================================================
# IP    Square_diff of (3.000000 - 8.000000)^2= 25.000000
#
# Numpy Square_diff of (3.000000 - 8.000000)^2= 25.000000
#
# ==================================================================
# ==================================================================
# IP    Square_diff of (4.000000 - 1.000000)^2= 9.000000
#
# Numpy Square_diff of (4.000000 - 1.000000)^2= 9.000000
#
# ==================================================================
# IP    Square_diff of (4.000000 - 2.000000)^2= 4.000000
#
# Numpy Square_diff of (4.000000 - 2.000000)^2= 4.000000
#
# ==================================================================
# IP    Square_diff of (4.000000 - 3.000000)^2= 1.000000
#
# Numpy Square_diff of (4.000000 - 3.000000)^2= 1.000000
#
# ==================================================================
# IP    Square_diff of (4.000000 - 4.000000)^2= 0.000000
#
# Numpy Square_diff of (4.000000 - 4.000000)^2= 0.000000
#
# ==================================================================
# IP    Square_diff of (4.000000 - 5.000000)^2= 1.000000
#
# Numpy Square_diff of (4.000000 - 5.000000)^2= 1.000000
#
# ==================================================================
# IP    Square_diff of (4.000000 - 6.000000)^2= 4.000000
#
# Numpy Square_diff of (4.000000 - 6.000000)^2= 4.000000
#
# ==================================================================
# IP    Square_diff of (4.000000 - 7.000000)^2= 9.000000
#
# Numpy Square_diff of (4.000000 - 7.000000)^2= 9.000000
#
# ==================================================================
# IP    Square_diff of (4.000000 - 8.000000)^2= 16.000000
#
# Numpy Square_diff of (4.000000 - 8.000000)^2= 16.000000
#
# ==================================================================
# ==================================================================
# IP    Square_diff of (5.000000 - 1.000000)^2= 16.000000
#
# Numpy Square_diff of (5.000000 - 1.000000)^2= 16.000000
#
# ==================================================================
# IP    Square_diff of (5.000000 - 2.000000)^2= 9.000000
#
# Numpy Square_diff of (5.000000 - 2.000000)^2= 9.000000
#
# ==================================================================
# IP    Square_diff of (5.000000 - 3.000000)^2= 4.000000
#
# Numpy Square_diff of (5.000000 - 3.000000)^2= 4.000000
#
# ==================================================================
# IP    Square_diff of (5.000000 - 4.000000)^2= 1.000000
#
# Numpy Square_diff of (5.000000 - 4.000000)^2= 1.000000
#
# ==================================================================
# IP    Square_diff of (5.000000 - 5.000000)^2= 0.000000
#
# Numpy Square_diff of (5.000000 - 5.000000)^2= 0.000000
#
# ==================================================================
# IP    Square_diff of (5.000000 - 6.000000)^2= 1.000000
#
# Numpy Square_diff of (5.000000 - 6.000000)^2= 1.000000
#
# ==================================================================
# IP    Square_diff of (5.000000 - 7.000000)^2= 4.000000
#
# Numpy Square_diff of (5.000000 - 7.000000)^2= 4.000000
#
# ==================================================================
# IP    Square_diff of (5.000000 - 8.000000)^2= 9.000000
#
# Numpy Square_diff of (5.000000 - 8.000000)^2= 9.000000
#
# ==================================================================
# ==================================================================
# IP    Square_diff of (6.000000 - 1.000000)^2= 25.000000
#
# Numpy Square_diff of (6.000000 - 1.000000)^2= 25.000000
#
# ==================================================================
# IP    Square_diff of (6.000000 - 2.000000)^2= 16.000000
#
# Numpy Square_diff of (6.000000 - 2.000000)^2= 16.000000
#
# ==================================================================
# IP    Square_diff of (6.000000 - 3.000000)^2= 9.000000
#
# Numpy Square_diff of (6.000000 - 3.000000)^2= 9.000000
#
# ==================================================================
# IP    Square_diff of (6.000000 - 4.000000)^2= 4.000000
#
# Numpy Square_diff of (6.000000 - 4.000000)^2= 4.000000
#
# ==================================================================
# IP    Square_diff of (6.000000 - 5.000000)^2= 1.000000
#
# Numpy Square_diff of (6.000000 - 5.000000)^2= 1.000000
#
# ==================================================================
# IP    Square_diff of (6.000000 - 6.000000)^2= 0.000000
#
# Numpy Square_diff of (6.000000 - 6.000000)^2= 0.000000
#
# ==================================================================
# IP    Square_diff of (6.000000 - 7.000000)^2= 1.000000
#
# Numpy Square_diff of (6.000000 - 7.000000)^2= 1.000000
#
# ==================================================================
# IP    Square_diff of (6.000000 - 8.000000)^2= 4.000000
#
# Numpy Square_diff of (6.000000 - 8.000000)^2= 4.000000
#
# ==================================================================
# ==================================================================
# IP    Square_diff of (7.000000 - 1.000000)^2= 36.000000
#
# Numpy Square_diff of (7.000000 - 1.000000)^2= 36.000000
#
# ==================================================================
# IP    Square_diff of (7.000000 - 2.000000)^2= 25.000000
#
# Numpy Square_diff of (7.000000 - 2.000000)^2= 25.000000
#
# ==================================================================
# IP    Square_diff of (7.000000 - 3.000000)^2= 16.000000
#
# Numpy Square_diff of (7.000000 - 3.000000)^2= 16.000000
#
# ==================================================================
# IP    Square_diff of (7.000000 - 4.000000)^2= 9.000000
#
# Numpy Square_diff of (7.000000 - 4.000000)^2= 9.000000
#
# ==================================================================
# IP    Square_diff of (7.000000 - 5.000000)^2= 4.000000
#
# Numpy Square_diff of (7.000000 - 5.000000)^2= 4.000000
#
# ==================================================================
# IP    Square_diff of (7.000000 - 6.000000)^2= 1.000000
#
# Numpy Square_diff of (7.000000 - 6.000000)^2= 1.000000
#
# ==================================================================
# IP    Square_diff of (7.000000 - 7.000000)^2= 0.000000
#
# Numpy Square_diff of (7.000000 - 7.000000)^2= 0.000000
#
# ==================================================================
# IP    Square_diff of (7.000000 - 8.000000)^2= 1.000000
#
# Numpy Square_diff of (7.000000 - 8.000000)^2= 1.000000
#
# ==================================================================
# ==================================================================
# IP    Square_diff of (8.000000 - 1.000000)^2= 49.000000
#
# Numpy Square_diff of (8.000000 - 1.000000)^2= 49.000000
#
# ==================================================================
# IP    Square_diff of (8.000000 - 2.000000)^2= 36.000000
#
# Numpy Square_diff of (8.000000 - 2.000000)^2= 36.000000
#
# ==================================================================
# IP    Square_diff of (8.000000 - 3.000000)^2= 25.000000
#
# Numpy Square_diff of (8.000000 - 3.000000)^2= 25.000000
#
# ==================================================================
# IP    Square_diff of (8.000000 - 4.000000)^2= 16.000000
#
# Numpy Square_diff of (8.000000 - 4.000000)^2= 16.000000
#
# ==================================================================
# IP    Square_diff of (8.000000 - 5.000000)^2= 9.000000
#
# Numpy Square_diff of (8.000000 - 5.000000)^2= 9.000000
#
# ==================================================================
# IP    Square_diff of (8.000000 - 6.000000)^2= 4.000000
#
# Numpy Square_diff of (8.000000 - 6.000000)^2= 4.000000
#
# ==================================================================
# IP    Square_diff of (8.000000 - 7.000000)^2= 1.000000
#
# Numpy Square_diff of (8.000000 - 7.000000)^2= 1.000000
#
# ==================================================================
# IP    Square_diff of (8.000000 - 8.000000)^2= 0.000000
#
# Numpy Square_diff of (8.000000 - 8.000000)^2= 0.000000
#
# ==================================================================
# Exit process
